# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import LabelEncoder

# %%
df = pd.read_csv(r"C:\Users\lenovo\Desktop\koleya\summer 3\my com data analysis\project\diabetes_prediction_dataset.csv")
df
# Out:
#        gender   age  hypertension  heart_disease smoking_history    bmi  \
# 0      Female  80.0             0              1           never  25.19
# 1      Female  54.0             0              0         No Info  27.32
# 2        Male  28.0             0              0           never  27.32
# 3      Female  36.0             0              0         current  23.45
# 4        Male  76.0             1              1         current  20.14
# ...       ...   ...           ...            ...             ...    ...
# 99995  Female  80.0             0              0         No Info  27.32
# 99996  Female   2.0             0              0         No Info  17.37
# 99997    Male  66.0             0              0          former  27.83
# 99998  Female  24.0             0              0           never  35.42
# 99999  Female  57.0             0              0         current  22.43
#
#        HbA1c_level  blood_glucose_level  diabetes
# 0              6.6                  140         0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 9 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   gender               100000 non-null  object
#  1   age                  100000 non-null  float64
#  2   hypertension         100000 non-null  int64
#  3   heart_disease        100000 non-null  int64
#  4   smoking_history      100000 non-null  object
#  5   bmi                  100000 non-null  float64
#  6   HbA1c_level          100000 non-null  float64
#  7   blood_glucose_level  100000 non-null  int64
#  8   diabetes             100000 non-null  int64
# dtypes: float64(3), int64(4), object(2)
# memory usage: 6.9+ MB

# %%
df.isna().sum()
# Out:
# gender                 0
# age                    0
# hypertension           0
# heart_disease          0
# smoking_history        0
# bmi                    0
# HbA1c_level            0
# blood_glucose_level    0
# diabetes               0
# dtype: int64

# %%
df['gender'].value_counts()
# Out:
# gender
# Female    58552
# Male      41430
# Other        18
# Name: count, dtype: int64

# %%
df['age'].unique()
# Out:
# array([80.  , 54.  , 28.  , 36.  , 76.  , 20.  , 44.  , 79.  , 42.  ,
#        32.  , 53.  , 78.  , 67.  , 15.  , 37.  , 40.  ,  5.  , 69.  ,
#        72.  ,  4.  , 30.  , 45.  , 43.  , 50.  , 41.  , 26.  , 34.  ,
#        73.  , 77.  , 66.  , 29.  , 60.  , 38.  ,  3.  , 57.  , 74.  ,
#        19.  , 46.  , 21.  , 59.  , 27.  , 13.  , 56.  ,  2.  ,  7.  ,
#        11.  ,  6.  , 55.  ,  9.  , 62.  , 47.  , 12.  , 68.  , 75.  ,
#        22.  , 58.  , 18.  , 24.  , 17.  , 25.  ,  0.08, 33.  , 16.  ,
#        61.  , 31.  ,  8.  , 49.  , 39.  , 65.  , 14.  , 70.  ,  0.56,
#        48.  , 51.  , 71.  ,  0.88, 64.  , 63.  , 52.  ,  0.16, 10.  ,
#        35.  , 23.  ,  0.64,  1.16,  1.64,  0.72,  1.88,  1.32,  0.8 ,
#         1.24,  1.  ,  1.8 ,  0.48,  1.56,  1.08,  0.24,  1.4 ,  0.4 ,
#         0.32,  1.72,  1.48])

# %%
df['hypertension'].value_counts()
# Out:
# hypertension
# 0    92515
# 1     7485
# Name: count, dtype: int64

# %%
df['heart_disease'].value_counts()
# Out:
# heart_disease
# 0    96058
# 1     3942
# Name: count, dtype: int64

# %%
df['smoking_history'].unique()
# Out:
# array(['never', 'No Info', 'current', 'former', 'ever', 'not current'],
#       dtype=object)

# %%
df['smoking_history'].value_counts()
# Out:
# smoking_history
# No Info        35816
# never          35095
# former          9352
# current         9286
# not current     6447
# ever            4004
# Name: count, dtype: int64

# %%
df['bmi'].unique()
# Out:
# array([25.19, 27.32, 23.45, ..., 59.42, 44.39, 60.52])

# %%
df['bmi'].value_counts()
# Out:
# bmi
# 27.32    25495
# 23.00      103
# 27.12      101
# 27.80      100
# 24.96      100
#          ...
# 58.23        1
# 48.18        1
# 55.57        1
# 57.07        1
# 60.52        1
# Name: count, Length: 4247, dtype: int64

# %%
df['HbA1c_level'].value_counts()
# Out:
# HbA1c_level
# 6.6    8540
# 5.7    8413
# 6.5    8362
# 5.8    8321
# 6.0    8295
# 6.2    8269
# 6.1    8048
# 3.5    7662
# 4.8    7597
# 4.5    7585
# 4.0    7542
# 5.0    7471
# 8.8     661
# 8.2     661
# 9.0     654
# 7.5     643
# 6.8     642
# 7.0     634
# Name: count, dtype: int64

# %%
df['blood_glucose_level'].value_counts()
# Out:
# blood_glucose_level
# 130    7794
# 159    7759
# 140    7732
# 160    7712
# 126    7702
# 145    7679
# 200    7600
# 155    7575
# 90     7112
# 80     7106
# 158    7026
# 100    7025
# 85     6901
# 280     729
# 300     674
# 240     636
# 260     635
# 220     603
# Name: count, dtype: int64

# %%
df['diabetes'].value_counts()
# Out:
# diabetes
# 0    91500
# 1     8500
# Name: count, dtype: int64

# %%
df.replace("Other",np.nan,inplace=True)

# %%
df.isna().sum()
# Out:
# gender                 18
# age                     0
# hypertension            0
# heart_disease           0
# smoking_history         0
# bmi                     0
# HbA1c_level             0
# blood_glucose_level     0
# diabetes                0
# dtype: int64

# %%
df.dropna(inplace=True)

# %%
df.isna().sum()
# Out:
# gender                 0
# age                    0
# hypertension           0
# heart_disease          0
# smoking_history        0
# bmi                    0
# HbA1c_level            0
# blood_glucose_level    0
# diabetes               0
# dtype: int64

# %%
# Create a pie chart
plt.figure(figsize=(8, 6))
plt.pie(df['diabetes'].value_counts(), labels=df['diabetes'].value_counts().index, autopct='%1.1f%%', startangle=90)
plt.title('diabetes Distribution')
plt.axis('equal')
plt.show()

# %%
# Create a pie chart
plt.figure(figsize=(8, 6))
plt.pie(df['gender'].value_counts(), labels=df['gender'].value_counts().index, autopct='%1.1f%%', startangle=90)
plt.title('Gender Distribution')
plt.axis('equal')
plt.show()

# %%
df['age'] = np.floor(df['age']).astype(int)

# %%
def categorize_age(age):
    if age <= 2:
        return 'Infants'
    elif age <= 12:
        return 'Children'
    elif age <= 35:
        return 'Teenagers and Young Adults'
    elif age <= 55:
        return 'Middle-aged Adults'
    else:
        return 'Older Adults'

# %%
# Apply categorization
df['age'] = df['age'].apply(categorize_age)
df['age'].value_counts()
# Out:
# age
# Older Adults                  30758
# Middle-aged Adults            29247
# Teenagers and Young Adults    27625
# Children                       9065
# Infants                        3287
# Name: count, dtype: int64

# %%
age_counts = df['age'].value_counts().sort_index()
# Create a bar plot
plt.figure(figsize=(10, 6))
plt.bar(age_counts.index, age_counts.values, color='skyblue')
plt.title('Bar Plot of Age')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.xticks(age_counts.index)  # Show all age values on x-axis
plt.show()

# %%
# Filter DataFrame for rows where age is 'Infants'
df_Infants = df[df['age'] == 'Infants']

# Count occurrences of 0 and 1 in the diabetes column for Infants
diabetes_counts = df_Infants['diabetes'].value_counts()

diabetes_counts
# Out:
# diabetes
# 0    3287
# Name: count, dtype: int64

# %%
# Filter DataFrame for rows where age is 'children'
df_children = df[df['age'] == 'Children']

# Count occurrences of 0 and 1 in the diabetes column for children
diabetes_counts = df_children['diabetes'].value_counts()

diabetes_counts
# Out:
# diabetes
# 0    9029
# 1      36
# Name: count, dtype: int64

# %%
df['age'].replace({'Children':np.nan, 'Infants':np.nan}, inplace=True)
df['age'].isna().sum()
# Out:
# 12352

# %%
df.dropna(inplace=True)
df.isna().sum()
# Out:
# gender                 0
# age                    0
# hypertension           0
# heart_disease          0
# smoking_history        0
# bmi                    0
# HbA1c_level            0
# blood_glucose_level    0
# diabetes               0
# dtype: int64

# %%
df.shape
# Out:
# (87630, 9)

# %%
age_counts = df['age'].value_counts().sort_index()
# Create a bar plot
plt.figure(figsize=(10, 6))
plt.bar(age_counts.index, age_counts.values, color='skyblue')
plt.title('Bar Plot of Age')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.xticks(age_counts.index)  # Show all age values on x-axis
plt.show()

# %%
df['smoking_history'].value_counts()
# Out:
# smoking_history
# never          33430
# No Info        25453
# former          9351
# current         9259
# not current     6138
# ever            3999
# Name: count, dtype: int64

# %%
df['smoking_history'].replace({'not current':'former', 'ever':'former'}, inplace=True)
df['smoking_history'].value_counts()
# Out:
# smoking_history
# never      33430
# No Info    25453
# former     19488
# current     9259
# Name: count, dtype: int64

# %%
# Create a pie chart
plt.figure(figsize=(8, 6))
plt.pie(df['smoking_history'].value_counts(), labels=df['smoking_history'].value_counts().index, autopct='%1.1f%%', startangle=90)
plt.title('smoking history Distribution')
plt.axis('equal')
plt.show()

# %%
def categorize_bmi(bmi):
    if bmi < 18.5:
        return 'Underweight'
    elif 18.5 <= bmi < 25:
        return 'Normal weight'
    elif 25 <= bmi < 30:
        return 'Overweight'
    else:
        return 'Obesity'

# %%
df['bmi'] = df['bmi'].apply(categorize_bmi)
df['bmi'].value_counts()
# Out:
# bmi
# Overweight       43160
# Obesity          23331
# Normal weight    19555
# Underweight       1584
# Name: count, dtype: int64

# %%
bmi_counts = df['bmi'].value_counts().sort_index()
# Create a bar plot
plt.figure(figsize=(10, 6))
plt.bar(bmi_counts.index, bmi_counts.values, color='skyblue')
plt.title('Bar Plot of bmi')
plt.xlabel('bmi')
plt.ylabel('Frequency')
plt.xticks(bmi_counts.index)  # Show all age values on x-axis
plt.show()

# %%
# Filter DataFrame for rows where bmi is 'Underweight'
df_Underweight = df[df['bmi'] == 'Underweight']

# Count occurrences of 0 and 1 in the diabetes column for Underweight
diabetes_counts = df_Underweight['diabetes'].value_counts()

diabetes_counts
# Out:
# diabetes
# 0    1539
# 1      45
# Name: count, dtype: int64

# %%
# Create a box plot
plt.figure(figsize=(8, 6))
sns.boxplot(y=df['HbA1c_level'])
plt.title('Box Plot of HbA1c_level')
plt.ylabel('HbA1c_level')
plt.show()

# %%
# Create a violin plot
plt.figure(figsize=(8, 6))
sns.boxplot(y=df['blood_glucose_level'])
plt.title('Violin Plot of Blood Glucose Level')
plt.ylabel('Blood Glucose Level (mg/dL)')
plt.show()

# %%
# Create a pie chart
plt.figure(figsize=(8, 6))
plt.pie(df['diabetes'].value_counts(), labels=df['diabetes'].value_counts().index, autopct='%1.1f%%', startangle=90)
plt.title('diabetes Distribution')
plt.axis('equal')
plt.show()

# %%
# Create a pie chart
plt.figure(figsize=(8, 6))
plt.pie(df['hypertension'].value_counts(), labels=df['hypertension'].value_counts().index, autopct='%1.1f%%', startangle=90)
plt.title('hypertension Distribution')
plt.axis('equal')
plt.show()

# %%
heart_disease_counts = df['heart_disease'].value_counts().sort_index()
# Create a bar plot
plt.figure(figsize=(10, 6))
plt.bar(heart_disease_counts.index, heart_disease_counts.values, color='skyblue')
plt.title('Bar Plot of heart disease')
plt.xlabel('heart disease')
plt.ylabel('Frequency')
plt.xticks(heart_disease_counts.index)  # Show all age values on x-axis
plt.show()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 87630 entries, 0 to 99999
# Data columns (total 9 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   gender               87630 non-null  object
#  1   age                  87630 non-null  object
#  2   hypertension         87630 non-null  int64
#  3   heart_disease        87630 non-null  int64
#  4   smoking_history      87630 non-null  object
#  5   bmi                  87630 non-null  object
#  6   HbA1c_level          87630 non-null  float64
#  7   blood_glucose_level  87630 non-null  int64
#  8   diabetes             87630 non-null  int64
# dtypes: float64(1), int64(4), object(4)
# memory usage: 6.7+ MB

# %%
# Save DataFrame to a new CSV file
df.to_csv(r"C:\Users\lenovo\Desktop\koleya\summer 3\my com data analysis\project\cleaned_diabetes_prediction_dataset.csv", index=False)  # index=False prevents writing row indices

# %%
df['gender'].replace({'Male':0, 'Female':1}, inplace=True)
df['gender'].value_counts()
# Out:
# gender
# 1    52569
# 0    35061
# Name: count, dtype: int64

# %%
age_category_mapping = {
    'Teenagers and Young Adults': 1,
    'Middle-aged Adults': 2,
    'Older Adults': 3
}
df['age'] = df['age'].map(age_category_mapping)
df['age'].value_counts()
# Out:
# age
# 3    30758
# 2    29247
# 1    27625
# Name: count, dtype: int64

# %%
smoking_history_mapping = {
    'No Info': 0,
    'never': 1,
    'former': 2,
    'current':3
    }
df['smoking_history'] = df['smoking_history'].map(smoking_history_mapping)
df['smoking_history'].value_counts()
# Out:
# smoking_history
# 1    33430
# 0    25453
# 2    19488
# 3     9259
# Name: count, dtype: int64

# %%
bmi_mapping = {
    'Underweight': 1,
    'Normal weight': 2,
    'Overweight': 3,
    'Obesity':4
    }
df['bmi'] = df['bmi'].map(bmi_mapping)
df['bmi'].value_counts()
# Out:
# bmi
# 3    43160
# 4    23331
# 2    19555
# 1     1584
# Name: count, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 87630 entries, 0 to 99999
# Data columns (total 9 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   gender               87630 non-null  int64
#  1   age                  87630 non-null  int64
#  2   hypertension         87630 non-null  int64
#  3   heart_disease        87630 non-null  int64
#  4   smoking_history      87630 non-null  int64
#  5   bmi                  87630 non-null  int64
#  6   HbA1c_level          87630 non-null  float64
#  7   blood_glucose_level  87630 non-null  int64
#  8   diabetes             87630 non-null  int64
# dtypes: float64(1), int64(8)
# memory usage: 6.7 MB

# %%
df['hypertension'].unique()
# Out:
# array([0, 1], dtype=int64)

# %%
df['heart_disease'].unique()
# Out:
# array([1, 0], dtype=int64)
